# %%
import re
import pandas as pd
import numpy as np
import networkx as nx
import matplotlib.pyplot as plt

# %%
ex = pd.read_csv('../data/ALL_EXHIBITIONS (post 90).csv', sep=';', encoding='utf-8', low_memory=False)
art = pd.read_csv('../data/ALL_ARTWORKS.csv', sep=',', encoding='utf-8', low_memory=False)

# %%
clean = pd.read_csv('../data/ALL_EXHIBITIONS (post 90 with collection).csv', sep=';', encoding='utf-8', low_memory=False)

# %%
ex.sample(3)
# Out:
#                                               exhibition  \
# 11246  Beautés animales : Muret (France), Centre de d...
# 155    Dessine le : Périgueux (France), Espace cultur...
# 31268  Matta in America : Paintings and Drawings of t...
#
#                                                    title  \
# 11246                                   Beautés animales
# 155                                           Dessine le
# 31268  Matta in America : Paintings and Drawings of t...
#
#                                                    place  \
# 11246       Muret (France), Centre de détention de Muret
# 155    Périgueux (France), Espace culturel François M...
# 31268               Miami (États-Unis), Miami Art Museum
#
#                                     museum                town  \
# 11246         Centre de détention de Muret      Muret (France)
# 155    Espace culturel François Mitterrand  Périgueux (France)
# 31268                     Miami Art Museum  Miami (États-Unis)
#
#                                      time  start_date    end_date  \
# 11246           21 janvier 2013-juin 2013  2013-01-21  2013-06-00
# 155    12 septembre 2007-30 novembre 2007  2007-09-12  2007-11-30
# 31268           22 mars 2002-02 juin 2002  2002-03-22  2002-06-02
#
#                                                 artworks
# 11246                  270000000003324 | 270000000002686
# 155    410000000001000 | 410000000000929 | 4100000000...
# 31268                                    150000000014710

# %%
# exposed = [[e for e in re.split(r' \| ', x['artworks'])] for i, x in ex.iterrows()]
# exposed = pd.Series(list(set([e for row in exposed for e in row])))

# %% [markdown]
# ex['collection'] = None
# ex['acquisition_year'] = None
# for i, e in ex.iterrows():
#     artworks = re.split(r' \| ', e['artworks'])
#     cols, years = [], []
#     for a in artworks:
#         col = art[art['_id'] == int(a)]['collection'].values[0]
#         if not pd.isnull(col):
#             cols.append(col)
#         year = art[art['_id'] == int(a)]['acquisition_year'].values[0]
#         if not pd.isnull(year):
#             years.append(year)
#     if len(years) > 0:
#         ex.at[i, 'acquisition_year'] = min(years)
#     if len(set(cols)) == 1:
#         ex.at[i, 'collection'] = cols[0]
#     if i % 10000 == 0:
#         print("Percentage:", int(i/len(ex) * 100), "total:", i)

# %%
for c in clean.columns:
    print("---- %s ---" % c)
    print(f'Count: {clean[c].count()}\tProportion: {round(100*clean[c].count()/clean["exhibition"].count(), 3)}%\t Diff: {- clean[c].count() + clean["exhibition"].count()}')
# Out:
# ---- Column1 ---
# Count: 60203	Proportion: 100.0%	 Diff: 0
# ---- exhibition ---
# Count: 60203	Proportion: 100.0%	 Diff: 0
# ---- title ---
# Count: 57051	Proportion: 94.764%	 Diff: 3152
# ---- place ---
# Count: 51440	Proportion: 85.444%	 Diff: 8763
# ---- museum ---
# Count: 51179	Proportion: 85.011%	 Diff: 9024
# ---- town ---
# Count: 51192	Proportion: 85.032%	 Diff: 9011
# ---- time ---
# Count: 57092	Proportion: 94.832%	 Diff: 3111
# ---- start_date ---
# Count: 57103	Proportion: 94.851%	 Diff: 3100
# ---- end_date ---
# Count: 57103	Proportion: 94.851%	 Diff: 3100
# ---- artworks ---
# Count: 60203	Proportion: 100.0%	 Diff: 0
# ---- collection ---
# Count: 58236	Proportion: 96.733%	 Diff: 1967
# ---- acquisition_year ---
# Count: 59492	Proportion: 98.819%	 Diff: 711

# %%
ex['town'].sample(10)
# Out:
# 53741               Montauban (France)
# 20773              Strasbourg (France)
# 44526                         Besançon
# 40196                   Lille (France)
# 23671                            Paris
# 10011    Samara (Fédération de Russie)
# 57376                           Bignan
# 45473               Marseille (France)
# 35895        Epinay-sur-Seine (France)
# 52938                Fribourg (Suisse)
# Name: town, dtype: object

# %%
# ex['collection'].sample(10)

# %%
clean['collection'].value_counts().plot(kind='bar', logy=True, figsize=(15,10))

# %%
bad = clean[pd.isnull(clean['town'])]
bad['collection'].value_counts()
new = bad['collection'].value_counts().reindex(clean['collection'].value_counts().index)
new.index = clean['collection'].value_counts().index
new.plot(kind='bar', figsize=(15,10))

# %%
subset = clean[(clean['collection'].str.contains("Musée national d'art moderne", na=False)) & (pd.isnull(clean['town']))]

# %%
# ex.to_csv("../data/ALL_EXHIBITIONS (post 90 with collection).csv", sep=';', encoding='utf-8',)

# %%
subset.sample(5)
# Out:
#        Column1                                         exhibition  \
# 40119    40151  Geneviève Asse, Stèles : 10 mars 2006-05 juin ...
# 8609      8613  La route bleue : Raoul Dufy en pays de Langres...
# 60096    60151  Accrochage "Made in France" en janvier 1997. L...
# 52983    53030                    Le mouvement des images : 2006-
# 60093    60148  Accrochage "Made in France"en janvier 1997. Le...
#
#                                                 title place museum town  \
# 40119                          Geneviève Asse, Stèles   NaN    NaN  NaN
# 8609   La route bleue : Raoul Dufy en pays de Langres   NaN    NaN  NaN
# 60096                     Accrochage "Made in France"   NaN    NaN  NaN
# 52983                         Le mouvement des images   NaN    NaN  NaN
# 60093                     Accrochage "Made in France"   NaN    NaN  NaN
#
#                             time  start_date    end_date  \
# 40119  10 mars 2006-05 juin 2006  2006-03-10  2006-06-05
# 8609    19 mai 2012-20 août 2012  2012-05-19  2012-08-20
# 60096                        NaN  1997-00-00  1997-00-00
# 52983                       2006  2006-00-00  2006-00-00
# 60093                        NaN  1997-00-00  1997-00-00
#
#                                 artworks  \
# 40119                    150000000701165
# 8609                     150000000020615
# 60096                    150000000020392
# 52983  150000000046197 | 150000000027355
# 60093                    150000000028340
#
#                                               collection  acquisition_year
# 40119  Musée national d'art moderne / Centre de créat...            2012.0
# 8609   Musée national d'art moderne / Centre de créat...            1963.0
# 60096  Musée national d'art moderne / Centre de créat...            1990.0
# 52983  Musée national d'art moderne / Centre de créat...            1996.0
# 60093  Musée national d'art moderne / Centre de créat...            1989.0
